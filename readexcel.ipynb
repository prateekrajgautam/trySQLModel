# %%
import pandas as pd

# %%
pydfdict = pd.read_excel("./Python Marks.xlsx",engine="openpyxl",sheet_name=None)
for sheet,df in pydfdict.items():
    if "pythonmid" in sheet.lower():
        print(sheet)
df["Student Id"]
# Out:
# PythonMID
# 0     590010560
# 1     590011054
# 2     590011148
# 3     590017001
# 4     590018678
# 5     590019018
# 6     590019112
# 7     590010703
# 8     590014628
# 9     590017891
# 10    590017901
# 11    590014501
# 12    590018547
# 13    590012969
# 14    590016294
# 15    590018609
# 16    590019257
# 17    590019258
# 18    590016063
# 19    590017572
# 20    590016400
# 21    590018019
# 22    590019268
# Name: Student Id, dtype: int64

# %%
# Out:
# {'sapid': 500094575, 'name': 'Divyanshu Singh', 'fname': 'Divyanshu', 'batch': 'BT-CSE-SPZ-CCVT-VII-B5', 'email': '500094575@stu.upes.ac.in'}
# {'sapid': 500094585, 'name': 'Arnav Sood', 'fname': 'Arnav', 'batch': 'BT-CSE-SPZ-CCVT-VII-B5', 'email': '500094585@stu.upes.ac.in'}
# {'sapid': 500095429, 'name': 'Ayush Verma', 'fname': 'Ayush', 'batch': 'BT-CSE-SPZ-CCVT-VII-B5', 'email': '500095429@stu.upes.ac.in'}
# {'sapid': 500094068, 'name': 'Akarsh Gupta', 'fname': 'Akarsh', 'batch': 'BT-CSE-SPZ-CCVT-VII-B4', 'email': '500094068@stu.upes.ac.in'}
# {'sapid': 500094118, 'name': 'Tushti Kulshreshtha', 'fname': 'Tushti', 'batch': 'BT-CSE-SPZ-CCVT-VII-B4', 'email': '500094118@stu.upes.ac.in'}
# {'sapid': 500094459, 'name': 'Syed Safi Hasnain Naqvi', 'fname': 'Syed', 'batch': 'BT-CSE-SPZ-CCVT-VII-B4', 'email': '500094459@stu.upes.ac.in'}
# {'sapid': 500093418, 'name': 'Amulya Garg', 'fname': 'Amulya', 'batch': 'BT-CSE-SPZ-CCVT-VII-B4', 'email': '500093418@stu.upes.ac.in'}
# {'sapid': 500094170, 'name': 'Aditya Choudhary', 'fname': 'Aditya', 'batch': 'BT-CSE-SPZ-CCVT-VII-B4', 'email': '500094170@stu.upes.ac.in'}
# {'sapid': 500095186, 'name': 'Amritanshu Shukla', 'fname': 'Amritanshu', 'batch': 'BT-CSE-SPZ-CCVT-VII-B5', 'email': '500095186@stu.upes.ac.in'}
# {'sapid': 500095673, 'name': 'Vilish Kumar', 'fname': 'Vilish', 'batch': 'BT-CSE-SPZ-CCVT-VII-B6', 'email': '500095673@stu.upes.ac.in'}
# {'sapid': 500096132, 'name': 'Ashish Kukreti', 'fname': 'Ashish', 'batch': 'BT-CSE-SPZ-CCVT-VII-B6', 'email': '500096132@stu.upes.ac.in'}
# {'sapid': 500096302, 'name': 'Rohan Bakshi', 'fname': 'Rohan', 'batch': 'BT-CSE-SPZ-CCVT-VII-B6', 'email': '500096302@stu.upes.ac.in'}
# {'sapid': 500095374, 'name': 'Jagpreet Singh', 'fname': 'Jagpreet', 'batch': 'BT-CSE-SPZ-CCVT-VII-B5', 'email': '500095374@stu.upes.ac.in'}
# {'sapid': 500095576, 'name': 'Sarthak Gupta', 'fname': 'Sarthak', 'batch': 'BT-CSE-SPZ-CCVT-VII-B5', 'email': '500095576@stu.upes.ac.in'}
# {'sapid': 500094583, 'name': 'Manvi Singh', 'fname': 'Manvi', 'batch': 'BT-CSE-SPZ-CCVT-VII-B5', 'email': '500094583@stu.upes.ac.in'}
# {'sapid': 500095011, 'name': 'Akshita Singh', 'fname': 'Akshita', 'batch': 'BT-CSE-SPZ-CCVT-VII-B5', 'email': '500095011@stu.upes.ac.in'}
# {'sapid': 500095651, 'name': 'Shambhavi Khanna', 'fname': 'Shambhavi', 'batch': 'BT-CSE-SPZ-CCVT-VII-B6', 'email': '500095651@stu.upes.ac.in'}
# {'sapid': 500095925, 'name': 'Dev Sharma', 'fname': 'Dev', 'batch': 'BT-CSE-SPZ-CCVT-VII-B6', 'email': '500095925@stu.upes.ac.in'}
# {'sapid': 500096088, 'name': 'Manya Juneja', 'fname': 'Manya', 'batch': 'BT-CSE-SPZ-CCVT-VII-B6', 'email': '500096088@stu.upes.ac.in'}
# {'sapid': 500094037, 'name': 'Aman Verma', 'fname': 'Aman', 'batch': 'BT-CSE-SPZ-CCVT-VII-B4', 'email': '500094037@stu.upes.ac.in'}
# {'sapid': 500094053, 'name': 'Vivek Patel', 'fname': 'Vivek', 'batch': 'BT-CSE-SPZ-CCVT-VII-B4', 'email': '500094053@stu.upes.ac.in'}
# {'sapid': 500095057, 'name': 'Riya Gupta', 'fname': 'Riya', 'batch': 'BT-CSE-SPZ-CCVT-VII-B5', 'email': '500095057@stu.upes.ac.in'}
# {'sapid': 500095603, 'name': 'Yash Agarwal', 'fname': 'Yash', 'batch': 'BT-CSE-SPZ-CCVT-VII-B5', 'email': '500095603@stu.upes.ac.in'}
# {'sapid': 500095633, 'name': 'Deepak Rana', 'fname': 'Deepak', 'batch': 'BT-CSE-SPZ-CCVT-VII-B6', 'email': '500095633@stu.upes.ac.in'}
# {'sapid': 500096244, 'name': 'Lavanya Raj', 'fname': 'Lavanya', 'batch': 'BT-CSE-SPZ-CCVT-VII-B6', 'email': '500096244@stu.upes.ac.in'}
# {'sapid': 500093629, 'name': 'Aryan Mehta', 'fname': 'Aryan', 'batch': 'BT-CSE-SPZ-CCVT-VII-B4', 'email': '500093629@stu.upes.ac.in'}
# {'sapid': 500094566, 'name': 'Saanvi Chaudhary', 'fname': 'Saanvi', 'batch': 'BT-CSE-SPZ-CCVT-VII-B5', 'email': '500094566@stu.upes.ac.in'}
# {'sapid': 500095565, 'name': 'Harsh Choudhary', 'fname': 'Harsh', 'batch': 'BT-CSE-SPZ-CCVT-VII-B5', 'email': '500095565@stu.upes.ac.in'}
# {'sapid': 500096086, 'name': 'Prince Rana', 'fname': 'Prince', 'batch': 'BT-CSE-SPZ-CCVT-VII-B6', 'email': '500096086@stu.upes.ac.in'}
# {'sapid': 500096258, 'name': 'Anuj Ramola', 'fname': 'Anuj', 'batch': 'BT-CSE-SPZ-CCVT-VII-B6', 'email': '500096258@stu.upes.ac.in'}
# {'sapid': 500095932, 'name': 'Shashank Paliwal', 'fname': 'Shashank', 'batch': 'BT-CSE-SPZ-CCVT-VII-B6', 'email': '500095932@stu.upes.ac.in'}
# {'sapid': 500096616, 'name': 'Parth Singh', 'fname': 'Parth', 'batch': 'BT-CSE-SPZ-CCVT-VII-B6', 'email': '500096616@stu.upes.ac.in'}
# {'sapid': 500093449, 'name': 'Siddhant Bhatnagar', 'fname': 'Siddhant', 'batch': 'BT-CSE-SPZ-CCVT-VII-B4', 'email': '500093449@stu.upes.ac.in'}
# {'sapid': 500096591, 'name': 'Chitra Sharma', 'fname': 'Chitra', 'batch': 'BT-CSE-SPZ-CCVT-VII-B6', 'email': '500096591@stu.upes.ac.in'}
# {'sapid': 500094565, 'name': 'Aashika Gupta', 'fname': 'Aashika', 'batch': 'BT-CSE-SPZ-CCVT-VII-B5', 'email': '500094565@stu.upes.ac.in'}
# {'sapid': 500094775, 'name': 'Vanshika Omer', 'fname': 'Vanshika', 'batch': 'BT-CSE-SPZ-CCVT-VII-B5', 'email': '500094775@stu.upes.ac.in'}
# {'sapid': 500095595, 'name': 'Aryan Ranjan', 'fname': 'Aryan', 'batch': 'BT-CSE-SPZ-CCVT-VII-B5', 'email': '500095595@stu.upes.ac.in'}
# {'sapid': 500095624, 'name': 'Khushi Nimawat', 'fname': 'Khushi', 'batch': 'BT-CSE-SPZ-CCVT-VII-B5', 'email': '500095624@stu.upes.ac.in'}
# {'sapid': 500094089, 'name': 'Vardan Kaushik', 'fname': 'Vardan', 'batch': 'BT-CSE-SPZ-CCVT-VII-B4', 'email': '500094089@stu.upes.ac.in'}
# {'sapid': 500095291, 'name': 'Shruti Agrawal', 'fname': 'Shruti', 'batch': 'BT-CSE-SPZ-CCVT-VII-B5', 'email': '500095291@stu.upes.ac.in'}
# {'sapid': 500095440, 'name': 'Asha Kadian', 'fname': 'Asha', 'batch': 'BT-CSE-SPZ-CCVT-VII-B5', 'email': '500095440@stu.upes.ac.in'}
# {'sapid': 500095542, 'name': 'Addya Pandey', 'fname': 'Addya', 'batch': 'BT-CSE-SPZ-CCVT-VII-B5', 'email': '500095542@stu.upes.ac.in'}
# {'sapid': 500096288, 'name': 'Chetanshi Pandey', 'fname': 'Chetanshi', 'batch': 'BT-CSE-SPZ-CCVT-VII-B6', 'email': '500096288@stu.upes.ac.in'}
# {'sapid': 500095601, 'name': 'Deepika Sharma', 'fname': 'Deepika', 'batch': 'BT-CSE-SPZ-CCVT-VII-B5', 'email': '500095601@stu.upes.ac.in'}
# {'sapid': 500093916, 'name': 'Soumil Kumar', 'fname': 'Soumil', 'batch': 'BT-CSE-SPZ-CCVT-VII-B4', 'email': '500093916@stu.upes.ac.in'}
# {'sapid': 500096495, 'name': 'Vamika Mahajan', 'fname': 'Vamika', 'batch': 'BT-CSE-SPZ-CCVT-VII-B6', 'email': '500096495@stu.upes.ac.in'}
# {'sapid': 500096507, 'name': 'Nirmol Kainth', 'fname': 'Nirmol', 'batch': 'BT-CSE-SPZ-CCVT-VII-B6', 'email': '500096507@stu.upes.ac.in'}
# {'sapid': 500093653, 'name': 'Kartik Saini', 'fname': 'Kartik', 'batch': 'BT-CSE-SPZ-CCVT-VII-B4', 'email': '500093653@stu.upes.ac.in'}
# {'sapid': 500094151, 'name': 'Priyanshu Singh', 'fname': 'Priyanshu', 'batch': 'BT-CSE-SPZ-CCVT-VII-B4', 'email': '500094151@stu.upes.ac.in'}
# {'sapid': 500094571, 'name': 'Shubhi Dixit', 'fname': 'Shubhi', 'batch': 'BT-CSE-SPZ-CCVT-VII-B5', 'email': '500094571@stu.upes.ac.in'}
# {'sapid': 500095594, 'name': 'Ayushi Sinha', 'fname': 'Ayushi', 'batch': 'BT-CSE-SPZ-CCVT-VII-B5', 'email': '500095594@stu.upes.ac.in'}
# {'sapid': 500095616, 'name': 'Drishti Sinha', 'fname': 'Drishti', 'batch': 'BT-CSE-SPZ-CCVT-VII-B5', 'email': '500095616@stu.upes.ac.in'}
# {'sapid': 500096448, 'name': 'Piklu De', 'fname': 'Piklu', 'batch': 'BT-CSE-SPZ-CCVT-VII-B6', 'email': '500096448@stu.upes.ac.in'}
# {'sapid': 500094103, 'name': 'Anishka Sinha', 'fname': 'Anishka', 'batch': 'BT-CSE-SPZ-CCVT-VII-B4', 'email': '500094103@stu.upes.ac.in'}
# {'sapid': 500094135, 'name': 'Vishakha Joshi', 'fname': 'Vishakha', 'batch': 'BT-CSE-SPZ-CCVT-VII-B4', 'email': '500094135@stu.upes.ac.in'}
# {'sapid': 500094049, 'name': 'Divay Sethi', 'fname': 'Divay', 'batch': 'BT-CSE-SPZ-CCVT-VII-B4', 'email': '500094049@stu.upes.ac.in'}
# {'sapid': 500094657, 'name': 'Anil Kumar', 'fname': 'Anil', 'batch': 'BT-CSE-SPZ-CCVT-VII-B5', 'email': '500094657@stu.upes.ac.in'}
# {'sapid': 500094799, 'name': 'Shivam Raj', 'fname': 'Shivam', 'batch': 'BT-CSE-SPZ-CCVT-VII-B5', 'email': '500094799@stu.upes.ac.in'}
# {'sapid': 500095629, 'name': 'YASH KUMAR', 'fname': 'YASH', 'batch': 'BT-CSE-SPZ-CCVT-VII-B5', 'email': '500095629@stu.upes.ac.in'}
# {'sapid': 500096351, 'name': 'Rudraksh Bhatnagar', 'fname': 'Rudraksh', 'batch': 'BT-CSE-SPZ-CCVT-VII-B6', 'email': '500096351@stu.upes.ac.in'}
# {'sapid': 500096554, 'name': 'Shubham Jaiswal', 'fname': 'Shubham', 'batch': 'BT-CSE-SPZ-CCVT-VII-B6', 'email': '500096554@stu.upes.ac.in'}
# {'sapid': 500094702, 'name': 'Siddharth Rawat', 'fname': 'Siddharth', 'batch': 'BT-CSE-SPZ-CCVT-VII-B5', 'email': '500094702@stu.upes.ac.in'}
# {'sapid': 500094905, 'name': 'Ayush Gurung', 'fname': 'Ayush', 'batch': 'BT-CSE-SPZ-CCVT-VII-B5', 'email': '500094905@stu.upes.ac.in'}
# {'sapid': 500093644, 'name': 'Bharat Singh Verma', 'fname': 'Bharat', 'batch': 'BT-CSE-SPZ-CCVT-VII-B4', 'email': '500093644@stu.upes.ac.in'}
# {'sapid': 500095581, 'name': 'Om Gupta', 'fname': 'Om', 'batch': 'BT-CSE-SPZ-CCVT-VII-B5', 'email': '500095581@stu.upes.ac.in'}
# {'sapid': 500093923, 'name': 'Bhoomi Tiwari', 'fname': 'Bhoomi', 'batch': 'BT-CSE-SPZ-CCVT-VII-B4', 'email': '500093923@stu.upes.ac.in'}
# {'sapid': 500094065, 'name': 'Vivaswan Shukla', 'fname': 'Vivaswan', 'batch': 'BT-CSE-SPZ-CCVT-VII-B4', 'email': '500094065@stu.upes.ac.in'}
# {'sapid': 500094152, 'name': 'Surya Subhey Verma', 'fname': 'Surya', 'batch': 'BT-CSE-SPZ-CCVT-VII-B4', 'email': '500094152@stu.upes.ac.in'}
# {'sapid': 500095439, 'name': 'Anushka Lomas', 'fname': 'Anushka', 'batch': 'BT-CSE-SPZ-CCVT-VII-B5', 'email': '500095439@stu.upes.ac.in'}
# {'sapid': 500096412, 'name': 'Shrey Gupta', 'fname': 'Shrey', 'batch': 'BT-CSE-SPZ-CCVT-VII-B6', 'email': '500096412@stu.upes.ac.in'}
# {'sapid': 500095574, 'name': 'Mayank Agrawal', 'fname': 'Mayank', 'batch': 'BT-CSE-SPZ-CCVT-VII-B5', 'email': '500095574@stu.upes.ac.in'}
# {'sapid': 500095554, 'name': 'Shrijay Pratap Bisht', 'fname': 'Shrijay', 'batch': 'BT-CSE-SPZ-CCVT-VII-B5', 'email': '500095554@stu.upes.ac.in'}
# {'sapid': 500095831, 'name': 'Vinamra Shahi', 'fname': 'Vinamra', 'batch': 'BT-CSE-SPZ-CCVT-VII-B6', 'email': '500095831@stu.upes.ac.in'}
# {'sapid': 500095834, 'name': 'Ayush Rawat', 'fname': 'Ayush', 'batch': 'BT-CSE-SPZ-CCVT-VII-B6', 'email': '500095834@stu.upes.ac.in'}
# {'sapid': 500095919, 'name': 'Nishant Popli', 'fname': 'Nishant', 'batch': 'BT-CSE-SPZ-CCVT-VII-B6', 'email': '500095919@stu.upes.ac.in'}
# {'sapid': 500094922, 'name': 'Hardik Singh', 'fname': 'Hardik', 'batch': 'BT-CSE-SPZ-CCVT-VII-B5', 'email': '500094922@stu.upes.ac.in'}
# {'sapid': 500095656, 'name': 'Anshika Saini', 'fname': 'Anshika', 'batch': 'BT-CSE-SPZ-CCVT-VII-B6', 'email': '500095656@stu.upes.ac.in'}
# {'sapid': 500096021, 'name': 'Natik Tyagi', 'fname': 'Natik', 'batch': 'BT-CSE-SPZ-CCVT-VII-B6', 'email': '500096021@stu.upes.ac.in'}
# {'sapid': 500096122, 'name': 'Lakshita Maheshwari', 'fname': 'Lakshita', 'batch': 'BT-CSE-SPZ-CCVT-VII-B6', 'email': '500096122@stu.upes.ac.in'}
# {'sapid': 500095937, 'name': 'Yash Gupta', 'fname': 'Yash', 'batch': 'BT-CSE-SPZ-CCVT-VII-B6', 'email': '500095937@stu.upes.ac.in'}
# {'sapid': 500096346, 'name': 'Siddharth Bansal', 'fname': 'Siddharth', 'batch': 'BT-CSE-SPZ-CCVT-VII-B6', 'email': '500096346@stu.upes.ac.in'}
# {'sapid': 500096400, 'name': 'Chahat Mittal', 'fname': 'Chahat', 'batch': 'BT-CSE-SPZ-CCVT-VII-B6', 'email': '500096400@stu.upes.ac.in'}
# {'sapid': 500093651, 'name': 'Manoj Sangwan', 'fname': 'Manoj', 'batch': 'BT-CSE-SPZ-CCVT-VII-B4', 'email': '500093651@stu.upes.ac.in'}
# {'sapid': 500093656, 'name': 'Jitean Sharma', 'fname': 'Jitean', 'batch': 'BT-CSE-SPZ-CCVT-VII-B4', 'email': '500093656@stu.upes.ac.in'}
# {'sapid': 500094117, 'name': 'Pratyush Badhani', 'fname': 'Pratyush', 'batch': 'BT-CSE-SPZ-CCVT-VII-B4', 'email': '500094117@stu.upes.ac.in'}
# {'sapid': 500095193, 'name': 'Adeep Kumar Dhiman', 'fname': 'Adeep', 'batch': 'BT-CSE-SPZ-CCVT-VII-B5', 'email': '500095193@stu.upes.ac.in'}
# {'sapid': 500095382, 'name': 'Damian Nicholas Dmello', 'fname': 'Damian', 'batch': 'BT-CSE-SPZ-CCVT-VII-B5', 'email': '500095382@stu.upes.ac.in'}
# {'sapid': 500095842, 'name': 'Yash Kumar', 'fname': 'Yash', 'batch': 'BT-CSE-SPZ-CCVT-VII-B6', 'email': '500095842@stu.upes.ac.in'}
# {'sapid': 500093617, 'name': 'Keshav Nanda', 'fname': 'Keshav', 'batch': 'BT-CSE-SPZ-CCVT-VII-B4', 'email': '500093617@stu.upes.ac.in'}
# {'sapid': 500094125, 'name': 'Priyvrat Upadhyay', 'fname': 'Priyvrat', 'batch': 'BT-CSE-SPZ-CCVT-VII-B4', 'email': '500094125@stu.upes.ac.in'}
# {'sapid': 500094136, 'name': 'Vaibhav Goyal', 'fname': 'Vaibhav', 'batch': 'BT-CSE-SPZ-CCVT-VII-B4', 'email': '500094136@stu.upes.ac.in'}
# {'sapid': 500093628, 'name': 'Samarth Sharma', 'fname': 'Samarth', 'batch': 'BT-CSE-SPZ-CCVT-VII-B4', 'email': '500093628@stu.upes.ac.in'}
# {'sapid': 500093659, 'name': 'Ayaan Azam', 'fname': 'Ayaan', 'batch': 'BT-CSE-SPZ-CCVT-VII-B4', 'email': '500093659@stu.upes.ac.in'}
# {'sapid': 500093677, 'name': 'Arpit Pandey', 'fname': 'Arpit', 'batch': 'BT-CSE-SPZ-CCVT-VII-B4', 'email': '500093677@stu.upes.ac.in'}
# {'sapid': 500093927, 'name': 'Arnesh Gupta', 'fname': 'Arnesh', 'batch': 'BT-CSE-SPZ-CCVT-VII-B4', 'email': '500093927@stu.upes.ac.in'}
# {'sapid': 500093948, 'name': 'Tushar Tomar', 'fname': 'Tushar', 'batch': 'BT-CSE-SPZ-CCVT-VII-B4', 'email': '500093948@stu.upes.ac.in'}
# {'sapid': 500093957, 'name': 'Kartik Manral', 'fname': 'Kartik', 'batch': 'BT-CSE-SPZ-CCVT-VII-B4', 'email': '500093957@stu.upes.ac.in'}
# {'sapid': 500093984, 'name': 'Jeevika Tuli', 'fname': 'Jeevika', 'batch': 'BT-CSE-SPZ-CCVT-VII-B4', 'email': '500093984@stu.upes.ac.in'}
# {'sapid': 500094046, 'name': 'Akshay Kumar Saini', 'fname': 'Akshay', 'batch': 'BT-CSE-SPZ-CCVT-VII-B4', 'email': '500094046@stu.upes.ac.in'}
# {'sapid': 500094054, 'name': 'Anshu Raj', 'fname': 'Anshu', 'batch': 'BT-CSE-SPZ-CCVT-VII-B4', 'email': '500094054@stu.upes.ac.in'}
# {'sapid': 500094083, 'name': 'Pahal Kumar Verma', 'fname': 'Pahal', 'batch': 'BT-CSE-SPZ-CCVT-VII-B4', 'email': '500094083@stu.upes.ac.in'}
# {'sapid': 500094696, 'name': 'Priyanshu .', 'fname': 'Priyanshu', 'batch': 'BT-CSE-SPZ-CCVT-VII-B5', 'email': '500094696@stu.upes.ac.in'}
# {'sapid': 500095437, 'name': 'Rachit Chauhan', 'fname': 'Rachit', 'batch': 'BT-CSE-SPZ-CCVT-VII-B5', 'email': '500095437@stu.upes.ac.in'}
# {'sapid': 500095825, 'name': 'Mudit Pandey', 'fname': 'Mudit', 'batch': 'BT-CSE-SPZ-CCVT-VII-B6', 'email': '500095825@stu.upes.ac.in'}
# {'sapid': 500095835, 'name': 'Yatharth Goyal', 'fname': 'Yatharth', 'batch': 'BT-CSE-SPZ-CCVT-VII-B6', 'email': '500095835@stu.upes.ac.in'}
# {'sapid': 500095836, 'name': 'AKSHAT ARORA', 'fname': 'AKSHAT', 'batch': 'BT-CSE-SPZ-CCVT-VII-B6', 'email': '500095836@stu.upes.ac.in'}
# {'sapid': 500095922, 'name': 'Jigyasu Mittal', 'fname': 'Jigyasu', 'batch': 'BT-CSE-SPZ-CCVT-VII-B6', 'email': '500095922@stu.upes.ac.in'}
# {'sapid': 500095936, 'name': 'Siddharth Kirti Gautam', 'fname': 'Siddharth', 'batch': 'BT-CSE-SPZ-CCVT-VII-B6', 'email': '500095936@stu.upes.ac.in'}

# %%
import pandas as pd 
def readFaculty():

    facultydf = pd.read_csv("./facultycontacts.csv")
    facultyDataList = []
    for i in range(0,facultydf.shape[0]):
        fseries = facultydf.loc[i]
        faculty = {
            "name" : fseries.at["First Name"] + " " if fseries.at["Middle Name"] == "" else f" {fseries.at["Middle Name"]} "  + fseries.at["Last Name"] ,
            "fname" : fseries.at["First Name"],
            "email" : fseries.at["E-mail Address"],
            "mobile" : fseries.at["Home Phone"] if fseries.at["Home Phone"] == "" else fseries.at["Mobile Phone"]    
        }
        facultyDataList.append(faculty)
    return facultyDataList
        
if __name__ == "__main__":
    facultyDataList= readFaculty()
# Out:
# First Name             Shivagunde
# Middle Name                   NaN
# Last Name      Saroj Snehal UPES
# Title                         NaN
# Suffix                        NaN
#                       ...
# Location                      NaN
# Web Page                      NaN
# Birthday                      NaN
# Anniversary                   NaN
# Notes                         NaN
# Name: 0, Length: 61, dtype: object
# First Name     Nitika
# Middle Name       NaN
# Last Name       Nigam
# Title             NaN
# Suffix            NaN
#                 ...
# Location          NaN
# Web Page          NaN
# Birthday          NaN
# Anniversary       NaN
# Notes             NaN
# Name: 1, Length: 61, dtype: object
# First Name     Rishi Dubey
# Middle Name            NaN
# Last Name              NaN
# Title                  NaN
# Suffix                 NaN
#                   ...
# Location               NaN
# Web Page               NaN
# Birthday               NaN
# Anniversary            NaN
# Notes                  NaN
# Name: 2, Length: 61, dtype: object
# First Name     Navya Yadav
# Middle Name            NaN
# Last Name              NaN
# Title                  NaN
# Suffix                 NaN
#                   ...
# Location               NaN
# Web Page               NaN
# Birthday               NaN
# Anniversary            NaN
# Notes                  NaN
# Name: 3, Length: 61, dtype: object
# First Name     Manish Singh Jetha
# Middle Name                   NaN
# Last Name                     NaN
# Title                         NaN
# Suffix                        NaN
#                       ...
# Location                      NaN
# Web Page                      NaN
# Birthday                      NaN
# Anniversary                   NaN
# Notes                         NaN
# Name: 4, Length: 61, dtype: object
# First Name     Lakshya Mehndiratta
# Middle Name                    NaN
# Last Name                      NaN
# Title                          NaN
# Suffix                         NaN
#                       ...
# Location                       NaN
# Web Page                       NaN
# Birthday                       NaN
# Anniversary                    NaN
# Notes                          NaN
# Name: 5, Length: 61, dtype: object
# First Name     khushi rohhila
# Middle Name               NaN
# Last Name                 NaN
# Title                     NaN
# Suffix                    NaN
#                     ...
# Location                  NaN
# Web Page                  NaN
# Birthday                  NaN
# Anniversary               NaN
# Notes                     NaN
# Name: 6, Length: 61, dtype: object
# First Name     Keertivallabh Sharma
# Middle Name                     NaN
# Last Name                       NaN
# Title                           NaN
# Suffix                          NaN
#                        ...
# Location                        NaN
# Web Page                        NaN
# Birthday                        NaN
# Anniversary                     NaN
# Notes                           NaN
# Name: 7, Length: 61, dtype: object
# First Name     Kanika Rawat
# Middle Name             NaN
# Last Name               NaN
# Title                   NaN
# Suffix                  NaN
#                    ...
# Location                NaN
# Web Page                NaN
# Birthday                NaN
# Anniversary             NaN
# Notes                   NaN
# Name: 8, Length: 61, dtype: object
# First Name     Jyotiraditya Singh
# Middle Name                   NaN
# Last Name                     NaN
# Title                         NaN
# Suffix                        NaN
#                       ...
# Location                      NaN
# Web Page                      NaN
# Birthday                      NaN
# Anniversary                   NaN
# Notes                         NaN
# Name: 9, Length: 61, dtype: object
# First Name     Diya Rana
# Middle Name          NaN
# Last Name            NaN
# Title                NaN
# Suffix               NaN
#                  ...
# Location             NaN
# Web Page             NaN
# Birthday             NaN
# Anniversary          NaN
# Notes                NaN
# Name: 10, Length: 61, dtype: object
# First Name     Barkha arora
# Middle Name             NaN
# Last Name               NaN
# Title                   NaN
# Suffix                  NaN
#                    ...
# Location                NaN
# Web Page                NaN
# Birthday                NaN
# Anniversary             NaN
# Notes                   NaN
# Name: 11, Length: 61, dtype: object
# First Name     Aryan Sinha
# Middle Name            NaN
# Last Name              NaN
# Title                  NaN
# Suffix                 NaN
#                   ...
# Location               NaN
# Web Page               NaN
# Birthday               NaN
# Anniversary            NaN
# Notes                  NaN
# Name: 12, Length: 61, dtype: object
# First Name     ANSH AHUJA
# Middle Name           NaN
# Last Name             NaN
# Title                 NaN
# Suffix                NaN
#                   ...
# Location              NaN
# Web Page              NaN
# Birthday              NaN
# Anniversary           NaN
# Notes                 NaN
# Name: 13, Length: 61, dtype: object
# First Name     Ayush
# Middle Name      NaN
# Last Name        NaN
# Title            NaN
# Suffix           NaN
#                ...
# Location         NaN
# Web Page         NaN
# Birthday         NaN
# Anniversary      NaN
# Notes            NaN
# Name: 14, Length: 61, dtype: object
# First Name     Anashvi Chauhan
# Middle Name                NaN
# Last Name                  NaN
# Title                      NaN
# Suffix                     NaN
#                     ...
# Location                   NaN
# Web Page                   NaN
# Birthday                   NaN
# Anniversary                NaN
# Notes                      NaN
# Name: 15, Length: 61, dtype: object
# First Name     Abhay Sharma
# Middle Name             NaN
# Last Name               NaN
# Title                   NaN
# Suffix                  NaN
#                    ...
# Location                NaN
# Web Page                NaN
# Birthday                NaN
# Anniversary             NaN
# Notes                   NaN
# Name: 16, Length: 61, dtype: object
# First Name     Abdul Qadir Kallatra
# Middle Name                     NaN
# Last Name                       NaN
# Title                           NaN
# Suffix                          NaN
#                        ...
# Location                        NaN
# Web Page                        NaN
# Birthday                        NaN
# Anniversary                     NaN
# Notes                           NaN
# Name: 17, Length: 61, dtype: object
# First Name     Tarun Nautiyal
# Middle Name               NaN
# Last Name                 NaN
# Title                     NaN
# Suffix                    NaN
#                     ...
# Location                  NaN
# Web Page                  NaN
# Birthday                  NaN
# Anniversary               NaN
# Notes                     NaN
# Name: 18, Length: 61, dtype: object
# First Name     Tanmay Gupta
# Middle Name             NaN
# Last Name               NaN
# Title                   NaN
# Suffix                  NaN
#                    ...
# Location                NaN
# Web Page                NaN
# Birthday                NaN
# Anniversary             NaN
# Notes                   NaN
# Name: 19, Length: 61, dtype: object
# First Name     Shreyash Kumar jha
# Middle Name                   NaN
# Last Name                     NaN
# Title                         NaN
# Suffix                        NaN
#                       ...
# Location                      NaN
# Web Page                      NaN
# Birthday                      NaN
# Anniversary                   NaN
# Notes                         NaN
# Name: 20, Length: 61, dtype: object
# First Name     Shashank Verma
# Middle Name               NaN
# Last Name                 NaN
# Title                     NaN
# Suffix                    NaN
#                     ...
# Location                  NaN
# Web Page                  NaN
# Birthday                  NaN
# Anniversary               NaN
# Notes                     NaN
# Name: 21, Length: 61, dtype: object
# First Name     Nishtha kanyal
# Middle Name               NaN
# Last Name                 NaN
# Title                     NaN
# Suffix                    NaN
#                     ...
# Location                  NaN
# Web Page                  NaN
# Birthday                  NaN
# Anniversary               NaN
# Notes                     NaN
# Name: 22, Length: 61, dtype: object
# First Name     Diya Bhardwaj
# Middle Name              NaN
# Last Name                NaN
# Title                    NaN
# Suffix                   NaN
#                    ...
# Location                 NaN
# Web Page                 NaN
# Birthday                 NaN
# Anniversary              NaN
# Notes                    NaN
# Name: 23, Length: 61, dtype: object
# First Name     Bhavya Singh
# Middle Name             NaN
# Last Name               NaN
# Title                   NaN
# Suffix                  NaN
#                    ...
# Location                NaN
# Web Page                NaN
# Birthday                NaN
# Anniversary             NaN
# Notes                   NaN
# Name: 24, Length: 61, dtype: object
# First Name     Aditya Gupta
# Middle Name             NaN
# Last Name               NaN
# Title                   NaN
# Suffix                  NaN
#                    ...
# Location                NaN
# Web Page                NaN
# Birthday                NaN
# Anniversary             NaN
# Notes                   NaN
# Name: 25, Length: 61, dtype: object
# First Name     Yuvraj singh Dhama
# Middle Name                   NaN
# Last Name                     NaN
# Title                         NaN
# Suffix                        NaN
#                       ...
# Location                      NaN
# Web Page                      NaN
# Birthday                      NaN
# Anniversary                   NaN
# Notes                         NaN
# Name: 26, Length: 61, dtype: object
# First Name     Sudhish Bisht
# Middle Name              NaN
# Last Name                NaN
# Title                    NaN
# Suffix                   NaN
#                    ...
# Location                 NaN
# Web Page                 NaN
# Birthday                 NaN
# Anniversary              NaN
# Notes                    NaN
# Name: 27, Length: 61, dtype: object
# First Name     Prabtej Singh
# Middle Name              NaN
# Last Name                NaN
# Title                    NaN
# Suffix                   NaN
#                    ...
# Location                 NaN
# Web Page                 NaN
# Birthday                 NaN
# Anniversary              NaN
# Notes                    NaN
# Name: 28, Length: 61, dtype: object
# First Name     Anurag yentrapragada
# Middle Name                     NaN
# Last Name                       NaN
# Title                           NaN
# Suffix                          NaN
#                        ...
# Location                        NaN
# Web Page                        NaN
# Birthday                        NaN
# Anniversary                     NaN
# Notes                           NaN
# Name: 29, Length: 61, dtype: object
# First Name     Shrey Sharma
# Middle Name             NaN
# Last Name               NaN
# Title                   NaN
# Suffix                  NaN
#                    ...
# Location                NaN
# Web Page                NaN
# Birthday                NaN
# Anniversary             NaN
# Notes                   NaN
# Name: 30, Length: 61, dtype: object
# First Name     Rishav Singh
# Middle Name             NaN
# Last Name               NaN
# Title                   NaN
# Suffix                  NaN
#                    ...
# Location                NaN
# Web Page                NaN
# Birthday                NaN
# Anniversary             NaN
# Notes                   NaN
# Name: 31, Length: 61, dtype: object
# First Name     Prabhu  Maken
# Middle Name              NaN
# Last Name                NaN
# Title                    NaN
# Suffix                   NaN
#                    ...
# Location                 NaN
# Web Page                 NaN
# Birthday                 NaN
# Anniversary              NaN
# Notes                    NaN
# Name: 32, Length: 61, dtype: object
# First Name     Khushi Chadha
# Middle Name              NaN
# Last Name                NaN
# Title                    NaN
# Suffix                   NaN
#                    ...
# Location                 NaN
# Web Page                 NaN
# Birthday                 NaN
# Anniversary              NaN
# Notes                    NaN
# Name: 33, Length: 61, dtype: object
# First Name     Ishit thapliyal
# Middle Name                NaN
# Last Name                  NaN
# Title                      NaN
# Suffix                     NaN
#                     ...
# Location                   NaN
# Web Page                   NaN
# Birthday                   NaN
# Anniversary                NaN
# Notes                      NaN
# Name: 34, Length: 61, dtype: object
# First Name     Harsh Nath Tiwari
# Middle Name                  NaN
# Last Name                    NaN
# Title                        NaN
# Suffix                       NaN
#                      ...
# Location                     NaN
# Web Page                     NaN
# Birthday                     NaN
# Anniversary                  NaN
# Notes                        NaN
# Name: 35, Length: 61, dtype: object
# First Name     Govind Heda
# Middle Name            NaN
# Last Name              NaN
# Title                  NaN
# Suffix                 NaN
#                   ...
# Location               NaN
# Web Page               NaN
# Birthday               NaN
# Anniversary            NaN
# Notes                  NaN
# Name: 36, Length: 61, dtype: object
# First Name     Divyansh Gupta
# Middle Name               NaN
# Last Name                 NaN
# Title                     NaN
# Suffix                    NaN
#                     ...
# Location                  NaN
# Web Page                  NaN
# Birthday                  NaN
# Anniversary               NaN
# Notes                     NaN
# Name: 37, Length: 61, dtype: object
# First Name     Anurag Kaushish
# Middle Name                NaN
# Last Name                  NaN
# Title                      NaN
# Suffix                     NaN
#                     ...
# Location                   NaN
# Web Page                   NaN
# Birthday                   NaN
# Anniversary                NaN
# Notes                      NaN
# Name: 38, Length: 61, dtype: object
# First Name     Ankur Gaharwar
# Middle Name               NaN
# Last Name                 NaN
# Title                     NaN
# Suffix                    NaN
#                     ...
# Location                  NaN
# Web Page                  NaN
# Birthday                  NaN
# Anniversary               NaN
# Notes                     NaN
# Name: 39, Length: 61, dtype: object
# First Name     Anant Singh
# Middle Name            NaN
# Last Name              NaN
# Title                  NaN
# Suffix                 NaN
#                   ...
# Location               NaN
# Web Page               NaN
# Birthday               NaN
# Anniversary            NaN
# Notes                  NaN
# Name: 40, Length: 61, dtype: object
# First Name     Aaditya vijayvargiya
# Middle Name                     NaN
# Last Name                       NaN
# Title                           NaN
# Suffix                          NaN
#                        ...
# Location                        NaN
# Web Page                        NaN
# Birthday                        NaN
# Anniversary                     NaN
# Notes                           NaN
# Name: 41, Length: 61, dtype: object
# First Name     Rishi Dubey
# Middle Name            NaN
# Last Name              NaN
# Title                  NaN
# Suffix                 NaN
#                   ...
# Location               NaN
# Web Page               NaN
# Birthday               NaN
# Anniversary            NaN
# Notes                  NaN
# Name: 42, Length: 61, dtype: object
# First Name     Navya Yadav
# Middle Name            NaN
# Last Name              NaN
# Title                  NaN
# Suffix                 NaN
#                   ...
# Location               NaN
# Web Page               NaN
# Birthday               NaN
# Anniversary            NaN
# Notes                  NaN
# Name: 43, Length: 61, dtype: object
# First Name     Manish Singh Jetha
# Middle Name                   NaN
# Last Name                     NaN
# Title                         NaN
# Suffix                        NaN
#                       ...
# Location                      NaN
# Web Page                      NaN
# Birthday                      NaN
# Anniversary                   NaN
# Notes                         NaN
# Name: 44, Length: 61, dtype: object
# First Name     Lakshya Mehndiratta
# Middle Name                    NaN
# Last Name                      NaN
# Title                          NaN
# Suffix                         NaN
#                       ...
# Location                       NaN
# Web Page                       NaN
# Birthday                       NaN
# Anniversary                    NaN
# Notes                          NaN
# Name: 45, Length: 61, dtype: object
# First Name     khushi rohhila
# Middle Name               NaN
# Last Name                 NaN
# Title                     NaN
# Suffix                    NaN
#                     ...
# Location                  NaN
# Web Page                  NaN
# Birthday                  NaN
# Anniversary               NaN
# Notes                     NaN
# Name: 46, Length: 61, dtype: object
# First Name     Keertivallabh Sharma
# Middle Name                     NaN
# Last Name                       NaN
# Title                           NaN
# Suffix                          NaN
#                        ...
# Location                        NaN
# Web Page                        NaN
# Birthday                        NaN
# Anniversary                     NaN
# Notes                           NaN
# Name: 47, Length: 61, dtype: object
# First Name     Kanika Rawat
# Middle Name             NaN
# Last Name               NaN
# Title                   NaN
# Suffix                  NaN
#                    ...
# Location                NaN
# Web Page                NaN
# Birthday                NaN
# Anniversary             NaN
# Notes                   NaN
# Name: 48, Length: 61, dtype: object
# First Name     Jyotiraditya Singh
# Middle Name                   NaN
# Last Name                     NaN
# Title                         NaN
# Suffix                        NaN
#                       ...
# Location                      NaN
# Web Page                      NaN
# Birthday                      NaN
# Anniversary                   NaN
# Notes                         NaN
# Name: 49, Length: 61, dtype: object
# First Name     Diya Rana
# Middle Name          NaN
# Last Name            NaN
# Title                NaN
# Suffix               NaN
#                  ...
# Location             NaN
# Web Page             NaN
# Birthday             NaN
# Anniversary          NaN
# Notes                NaN
# Name: 50, Length: 61, dtype: object
# First Name     Barkha arora
# Middle Name             NaN
# Last Name               NaN
# Title                   NaN
# Suffix                  NaN
#                    ...
# Location                NaN
# Web Page                NaN
# Birthday                NaN
# Anniversary             NaN
# Notes                   NaN
# Name: 51, Length: 61, dtype: object
# First Name     Aryan Sinha
# Middle Name            NaN
# Last Name              NaN
# Title                  NaN
# Suffix                 NaN
#                   ...
# Location               NaN
# Web Page               NaN
# Birthday               NaN
# Anniversary            NaN
# Notes                  NaN
# Name: 52, Length: 61, dtype: object
# First Name     ANSH AHUJA
# Middle Name           NaN
# Last Name             NaN
# Title                 NaN
# Suffix                NaN
#                   ...
# Location              NaN
# Web Page              NaN
# Birthday              NaN
# Anniversary           NaN
# Notes                 NaN
# Name: 53, Length: 61, dtype: object
# First Name     Ayush
# Middle Name      NaN
# Last Name        NaN
# Title            NaN
# Suffix           NaN
#                ...
# Location         NaN
# Web Page         NaN
# Birthday         NaN
# Anniversary      NaN
# Notes            NaN
# Name: 54, Length: 61, dtype: object
# First Name     Anashvi Chauhan
# Middle Name                NaN
# Last Name                  NaN
# Title                      NaN
# Suffix                     NaN
#                     ...
# Location                   NaN
# Web Page                   NaN
# Birthday                   NaN
# Anniversary                NaN
# Notes                      NaN
# Name: 55, Length: 61, dtype: object
# First Name     Abhay Sharma
# Middle Name             NaN
# Last Name               NaN
# Title                   NaN
# Suffix                  NaN
#                    ...
# Location                NaN
# Web Page                NaN
# Birthday                NaN
# Anniversary             NaN
# Notes                   NaN
# Name: 56, Length: 61, dtype: object
# First Name     Abdul Qadir Kallatra
# Middle Name                     NaN
# Last Name                       NaN
# Title                           NaN
# Suffix                          NaN
#                        ...
# Location                        NaN
# Web Page                        NaN
# Birthday                        NaN
# Anniversary                     NaN
# Notes                           NaN
# Name: 57, Length: 61, dtype: object
# First Name     Tarun Nautiyal
# Middle Name               NaN
# Last Name                 NaN
# Title                     NaN
# Suffix                    NaN
#                     ...
# Location                  NaN
# Web Page                  NaN
# Birthday                  NaN
# Anniversary               NaN
# Notes                     NaN
# Name: 58, Length: 61, dtype: object
# First Name     Tanmay Gupta
# Middle Name             NaN
# Last Name               NaN
# Title                   NaN
# Suffix                  NaN
#                    ...
# Location                NaN
# Web Page                NaN
# Birthday                NaN
# Anniversary             NaN
# Notes                   NaN
# Name: 59, Length: 61, dtype: object
# First Name     Shreyash Kumar jha
# Middle Name                   NaN
# Last Name                     NaN
# Title                         NaN
# Suffix                        NaN
#                       ...
# Location                      NaN
# Web Page                      NaN
# Birthday                      NaN
# Anniversary                   NaN
# Notes                         NaN
# Name: 60, Length: 61, dtype: object
# First Name     Shashank Verma
# Middle Name               NaN
# Last Name                 NaN
# Title                     NaN
# Suffix                    NaN
#                     ...
# Location                  NaN
# Web Page                  NaN
# Birthday                  NaN
# Anniversary               NaN
# Notes                     NaN
# Name: 61, Length: 61, dtype: object
# First Name     Nishtha kanyal
# Middle Name               NaN
# Last Name                 NaN
# Title                     NaN
# Suffix                    NaN
#                     ...
# Location                  NaN
# Web Page                  NaN
# Birthday                  NaN
# Anniversary               NaN
# Notes                     NaN
# Name: 62, Length: 61, dtype: object
# First Name     Diya Bhardwaj
# Middle Name              NaN
# Last Name                NaN
# Title                    NaN
# Suffix                   NaN
#                    ...
# Location                 NaN
# Web Page                 NaN
# Birthday                 NaN
# Anniversary              NaN
# Notes                    NaN
# Name: 63, Length: 61, dtype: object
# First Name     Bhavya Singh
# Middle Name             NaN
# Last Name               NaN
# Title                   NaN
# Suffix                  NaN
#                    ...
# Location                NaN
# Web Page                NaN
# Birthday                NaN
# Anniversary             NaN
# Notes                   NaN
# Name: 64, Length: 61, dtype: object
# First Name     Aditya Gupta
# Middle Name             NaN
# Last Name               NaN
# Title                   NaN
# Suffix                  NaN
#                    ...
# Location                NaN
# Web Page                NaN
# Birthday                NaN
# Anniversary             NaN
# Notes                   NaN
# Name: 65, Length: 61, dtype: object
# First Name     Yuvraj singh Dhama
# Middle Name                   NaN
# Last Name                     NaN
# Title                         NaN
# Suffix                        NaN
#                       ...
# Location                      NaN
# Web Page                      NaN
# Birthday                      NaN
# Anniversary                   NaN
# Notes                         NaN
# Name: 66, Length: 61, dtype: object
# First Name     Sudhish Bisht
# Middle Name              NaN
# Last Name                NaN
# Title                    NaN
# Suffix                   NaN
#                    ...
# Location                 NaN
# Web Page                 NaN
# Birthday                 NaN
# Anniversary              NaN
# Notes                    NaN
# Name: 67, Length: 61, dtype: object
# First Name     Prabtej Singh
# Middle Name              NaN
# Last Name                NaN
# Title                    NaN
# Suffix                   NaN
#                    ...
# Location                 NaN
# Web Page                 NaN
# Birthday                 NaN
# Anniversary              NaN
# Notes                    NaN
# Name: 68, Length: 61, dtype: object
# First Name     Anurag yentrapragada
# Middle Name                     NaN
# Last Name                       NaN
# Title                           NaN
# Suffix                          NaN
#                        ...
# Location                        NaN
# Web Page                        NaN
# Birthday                        NaN
# Anniversary                     NaN
# Notes                           NaN
# Name: 69, Length: 61, dtype: object
# First Name     Shrey Sharma
# Middle Name             NaN
# Last Name               NaN
# Title                   NaN
# Suffix                  NaN
#                    ...
# Location                NaN
# Web Page                NaN
# Birthday                NaN
# Anniversary             NaN
# Notes                   NaN
# Name: 70, Length: 61, dtype: object
# First Name     Rishav Singh
# Middle Name             NaN
# Last Name               NaN
# Title                   NaN
# Suffix                  NaN
#                    ...
# Location                NaN
# Web Page                NaN
# Birthday                NaN
# Anniversary             NaN
# Notes                   NaN
# Name: 71, Length: 61, dtype: object
# First Name     Prabhu  Maken
# Middle Name              NaN
# Last Name                NaN
# Title                    NaN
# Suffix                   NaN
#                    ...
# Location                 NaN
# Web Page                 NaN
# Birthday                 NaN
# Anniversary              NaN
# Notes                    NaN
# Name: 72, Length: 61, dtype: object
# First Name     Khushi Chadha
# Middle Name              NaN
# Last Name                NaN
# Title                    NaN
# Suffix                   NaN
#                    ...
# Location                 NaN
# Web Page                 NaN
# Birthday                 NaN
# Anniversary              NaN
# Notes                    NaN
# Name: 73, Length: 61, dtype: object
# First Name     Ishit thapliyal
# Middle Name                NaN
# Last Name                  NaN
# Title                      NaN
# Suffix                     NaN
#                     ...
# Location                   NaN
# Web Page                   NaN
# Birthday                   NaN
# Anniversary                NaN
# Notes                      NaN
# Name: 74, Length: 61, dtype: object
# First Name     Harsh Nath Tiwari
# Middle Name                  NaN
# Last Name                    NaN
# Title                        NaN
# Suffix                       NaN
#                      ...
# Location                     NaN
# Web Page                     NaN
# Birthday                     NaN
# Anniversary                  NaN
# Notes                        NaN
# Name: 75, Length: 61, dtype: object
# First Name     Govind Heda
# Middle Name            NaN
# Last Name              NaN
# Title                  NaN
# Suffix                 NaN
#                   ...
# Location               NaN
# Web Page               NaN
# Birthday               NaN
# Anniversary            NaN
# Notes                  NaN
# Name: 76, Length: 61, dtype: object
# First Name     Divyansh Gupta
# Middle Name               NaN
# Last Name                 NaN
# Title                     NaN
# Suffix                    NaN
#                     ...
# Location                  NaN
# Web Page                  NaN
# Birthday                  NaN
# Anniversary               NaN
# Notes                     NaN
# Name: 77, Length: 61, dtype: object
# First Name     Anurag Kaushish
# Middle Name                NaN
# Last Name                  NaN
# Title                      NaN
# Suffix                     NaN
#                     ...
# Location                   NaN
# Web Page                   NaN
# Birthday                   NaN
# Anniversary                NaN
# Notes                      NaN
# Name: 78, Length: 61, dtype: object
# First Name     Ankur Gaharwar
# Middle Name               NaN
# Last Name                 NaN
# Title                     NaN
# Suffix                    NaN
#                     ...
# Location                  NaN
# Web Page                  NaN
# Birthday                  NaN
# Anniversary               NaN
# Notes                     NaN
# Name: 79, Length: 61, dtype: object
# First Name     Anant Singh
# Middle Name            NaN
# Last Name              NaN
# Title                  NaN
# Suffix                 NaN
#                   ...
# Location               NaN
# Web Page               NaN
# Birthday               NaN
# Anniversary            NaN
# Notes                  NaN
# Name: 80, Length: 61, dtype: object
# First Name     Aaditya vijayvargiya
# Middle Name                     NaN
# Last Name                       NaN
# Title                           NaN
# Suffix                          NaN
#                        ...
# Location                        NaN
# Web Page                        NaN
# Birthday                        NaN
# Anniversary                     NaN
# Notes                           NaN
# Name: 81, Length: 61, dtype: object
# First Name     Piyush
# Middle Name       NaN
# Last Name         NaN
# Title             NaN
# Suffix            NaN
#                 ...
# Location          NaN
# Web Page          NaN
# Birthday          NaN
# Anniversary       NaN
# Notes             NaN
# Name: 82, Length: 61, dtype: object
# First Name     Krishna Maurya
# Middle Name               NaN
# Last Name                 NaN
# Title                     NaN
# Suffix                    NaN
#                     ...
# Location                  NaN
# Web Page                  NaN
# Birthday                  NaN
# Anniversary               NaN
# Notes                     NaN
# Name: 83, Length: 61, dtype: object
# First Name     Anuj Gupta
# Middle Name           NaN
# Last Name             NaN
# Title                 NaN
# Suffix                NaN
#                   ...
# Location              NaN
# Web Page              NaN
# Birthday              NaN
# Anniversary           NaN
# Notes                 NaN
# Name: 84, Length: 61, dtype: object
# First Name     Ujjwal Kaushik
# Middle Name               NaN
# Last Name                 NaN
# Title                     NaN
# Suffix                    NaN
#                     ...
# Location                  NaN
# Web Page                  NaN
# Birthday                  NaN
# Anniversary               NaN
# Notes                     NaN
# Name: 85, Length: 61, dtype: object
# First Name     Tushar Sharma
# Middle Name              NaN
# Last Name                NaN
# Title                    NaN
# Suffix                   NaN
#                    ...
# Location                 NaN
# Web Page                 NaN
# Birthday                 NaN
# Anniversary              NaN
# Notes                    NaN
# Name: 86, Length: 61, dtype: object
# First Name     Vanshika Agarwal
# Middle Name                 NaN
# Last Name                   NaN
# Title                       NaN
# Suffix                      NaN
#                      ...
# Location                    NaN
# Web Page                    NaN
# Birthday                    NaN
# Anniversary                 NaN
# Notes                       NaN
# Name: 87, Length: 61, dtype: object
# First Name     Manjari Yagnik
# Middle Name               NaN
# Last Name                 NaN
# Title                     NaN
# Suffix                    NaN
#                     ...
# Location                  NaN
# Web Page                  NaN
# Birthday                  NaN
# Anniversary               NaN
# Notes                     NaN
# Name: 88, Length: 61, dtype: object
# First Name     Jahnavi Singh Chauhan
# Middle Name                      NaN
# Last Name                        NaN
# Title                            NaN
# Suffix                           NaN
#                        ...
# Location                         NaN
# Web Page                         NaN
# Birthday                         NaN
# Anniversary                      NaN
# Notes                            NaN
# Name: 89, Length: 61, dtype: object
# First Name     Jaanhvi Saxena
# Middle Name               NaN
# Last Name                 NaN
# Title                     NaN
# Suffix                    NaN
#                     ...
# Location                  NaN
# Web Page                  NaN
# Birthday                  NaN
# Anniversary               NaN
# Notes                     NaN
# Name: 90, Length: 61, dtype: object
# First Name     Deepanshu Kumar Jindal
# Middle Name                       NaN
# Last Name                         NaN
# Title                             NaN
# Suffix                            NaN
#                         ...
# Location                          NaN
# Web Page                          NaN
# Birthday                          NaN
# Anniversary                       NaN
# Notes                             NaN
# Name: 91, Length: 61, dtype: object
# First Name     Rishitt Gupta
# Middle Name              NaN
# Last Name                NaN
# Title                    NaN
# Suffix                   NaN
#                    ...
# Location                 NaN
# Web Page                 NaN
# Birthday                 NaN
# Anniversary              NaN
# Notes                    NaN
# Name: 92, Length: 61, dtype: object
# First Name     Vyom Singhal
# Middle Name             NaN
# Last Name               NaN
# Title                   NaN
# Suffix                  NaN
#                    ...
# Location                NaN
# Web Page                NaN
# Birthday                NaN
# Anniversary             NaN
# Notes                   NaN
# Name: 93, Length: 61, dtype: object
# First Name     Rakshita Garg
# Middle Name              NaN
# Last Name                NaN
# Title                    NaN
# Suffix                   NaN
#                    ...
# Location                 NaN
# Web Page                 NaN
# Birthday                 NaN
# Anniversary              NaN
# Notes                    NaN
# Name: 94, Length: 61, dtype: object
# First Name     Paras Verma
# Middle Name            NaN
# Last Name              NaN
# Title                  NaN
# Suffix                 NaN
#                   ...
# Location               NaN
# Web Page               NaN
# Birthday               NaN
# Anniversary            NaN
# Notes                  NaN
# Name: 95, Length: 61, dtype: object
# First Name     Panshul Saxena
# Middle Name               NaN
# Last Name                 NaN
# Title                     NaN
# Suffix                    NaN
#                     ...
# Location                  NaN
# Web Page                  NaN
# Birthday                  NaN
# Anniversary               NaN
# Notes                     NaN
# Name: 96, Length: 61, dtype: object
# First Name     Khushi Dasoar
# Middle Name              NaN
# Last Name                NaN
# Title                    NaN
# Suffix                   NaN
#                    ...
# Location                 NaN
# Web Page                 NaN
# Birthday                 NaN
# Anniversary              NaN
# Notes                    NaN
# Name: 97, Length: 61, dtype: object
# First Name     Gurmehr Singh Gulati
# Middle Name                     NaN
# Last Name                       NaN
# Title                           NaN
# Suffix                          NaN
#                        ...
# Location                        NaN
# Web Page                        NaN
# Birthday                        NaN
# Anniversary                     NaN
# Notes                           NaN
# Name: 98, Length: 61, dtype: object
# First Name     Divya Darshan Tiwari
# Middle Name                     NaN
# Last Name                       NaN
# Title                           NaN
# Suffix                          NaN
#                        ...
# Location                        NaN
# Web Page                        NaN
# Birthday                        NaN
# Anniversary                     NaN
# Notes                           NaN
# Name: 99, Length: 61, dtype: object
# First Name      Ayush Dey
# Middle Name           NaN
# Last Name      Srivastava
# Title                 Dr.
# Suffix                NaN
#                   ...
# Location              NaN
# Web Page              NaN
# Birthday              NaN
# Anniversary           NaN
# Notes                 NaN
# Name: 100, Length: 61, dtype: object
# First Name     Aryan Somesh Gupta
# Middle Name                   NaN
# Last Name                Majumder
# Title                         NaN
# Suffix                        NaN
#                       ...
# Location                      NaN
# Web Page                      NaN
# Birthday                      NaN
# Anniversary                   NaN
# Notes                         NaN
# Name: 101, Length: 61, dtype: object
# First Name     Piyush
# Middle Name       NaN
# Last Name         NaN
# Title             NaN
# Suffix            NaN
#                 ...
# Location          NaN
# Web Page          NaN
# Birthday          NaN
# Anniversary       NaN
# Notes             NaN
# Name: 102, Length: 61, dtype: object
# First Name     Krishna Maurya
# Middle Name               NaN
# Last Name                 NaN
# Title                     NaN
# Suffix                    NaN
#                     ...
# Location                  NaN
# Web Page                  NaN
# Birthday                  NaN
# Anniversary               NaN
# Notes                     NaN
# Name: 103, Length: 61, dtype: object
# First Name     Anuj Gupta
# Middle Name           NaN
# Last Name             NaN
# Title                 NaN
# Suffix                NaN
#                   ...
# Location              NaN
# Web Page              NaN
# Birthday              NaN
# Anniversary           NaN
# Notes                 NaN
# Name: 104, Length: 61, dtype: object
# First Name     Ujjwal Kaushik
# Middle Name               NaN
# Last Name                 NaN
# Title                     NaN
# Suffix                    NaN
#                     ...
# Location                  NaN
# Web Page                  NaN
# Birthday                  NaN
# Anniversary               NaN
# Notes                     NaN
# Name: 105, Length: 61, dtype: object
# First Name     Tushar Sharma
# Middle Name              NaN
# Last Name                NaN
# Title                    NaN
# Suffix                   NaN
#                    ...
# Location                 NaN
# Web Page                 NaN
# Birthday                 NaN
# Anniversary              NaN
# Notes                    NaN
# Name: 106, Length: 61, dtype: object
# First Name     Vanshika Agarwal
# Middle Name                 NaN
# Last Name                   NaN
# Title                       NaN
# Suffix                      NaN
#                      ...
# Location                    NaN
# Web Page                    NaN
# Birthday                    NaN
# Anniversary                 NaN
# Notes                       NaN
# Name: 107, Length: 61, dtype: object
# First Name     Manjari Yagnik
# Middle Name               NaN
# Last Name                 NaN
# Title                     NaN
# Suffix                    NaN
#                     ...
# Location                  NaN
# Web Page                  NaN
# Birthday                  NaN
# Anniversary               NaN
# Notes                     NaN
# Name: 108, Length: 61, dtype: object
# First Name     Jahnavi Singh Chauhan
# Middle Name                      NaN
# Last Name                        NaN
# Title                            NaN
# Suffix                           NaN
#                        ...
# Location                         NaN
# Web Page                         NaN
# Birthday                         NaN
# Anniversary                      NaN
# Notes                            NaN
# Name: 109, Length: 61, dtype: object
# First Name     Jaanhvi Saxena
# Middle Name               NaN
# Last Name                 NaN
# Title                     NaN
# Suffix                    NaN
#                     ...
# Location                  NaN
# Web Page                  NaN
# Birthday                  NaN
# Anniversary               NaN
# Notes                     NaN
# Name: 110, Length: 61, dtype: object
# First Name     Deepanshu Kumar Jindal
# Middle Name                       NaN
# Last Name                         NaN
# Title                             NaN
# Suffix                            NaN
#                         ...
# Location                          NaN
# Web Page                          NaN
# Birthday                          NaN
# Anniversary                       NaN
# Notes                             NaN
# Name: 111, Length: 61, dtype: object
# First Name     Rishitt Gupta
# Middle Name              NaN
# Last Name                NaN
# Title                    NaN
# Suffix                   NaN
#                    ...
# Location                 NaN
# Web Page                 NaN
# Birthday                 NaN
# Anniversary              NaN
# Notes                    NaN
# Name: 112, Length: 61, dtype: object
# First Name     Vyom Singhal
# Middle Name             NaN
# Last Name               NaN
# Title                   NaN
# Suffix                  NaN
#                    ...
# Location                NaN
# Web Page                NaN
# Birthday                NaN
# Anniversary             NaN
# Notes                   NaN
# Name: 113, Length: 61, dtype: object
# First Name     Rakshita Garg
# Middle Name              NaN
# Last Name                NaN
# Title                    NaN
# Suffix                   NaN
#                    ...
# Location                 NaN
# Web Page                 NaN
# Birthday                 NaN
# Anniversary              NaN
# Notes                    NaN
# Name: 114, Length: 61, dtype: object
# First Name     Paras Verma
# Middle Name            NaN
# Last Name              NaN
# Title                  NaN
# Suffix                 NaN
#                   ...
# Location               NaN
# Web Page               NaN
# Birthday               NaN
# Anniversary            NaN
# Notes                  NaN
# Name: 115, Length: 61, dtype: object
# First Name     Panshul Saxena
# Middle Name               NaN
# Last Name                 NaN
# Title                     NaN
# Suffix                    NaN
#                     ...
# Location                  NaN
# Web Page                  NaN
# Birthday                  NaN
# Anniversary               NaN
# Notes                     NaN
# Name: 116, Length: 61, dtype: object
# First Name     Khushi Dasoar
# Middle Name              NaN
# Last Name                NaN
# Title                    NaN
# Suffix                   NaN
#                    ...
# Location                 NaN
# Web Page                 NaN
# Birthday                 NaN
# Anniversary              NaN
# Notes                    NaN
# Name: 117, Length: 61, dtype: object
# First Name     Gurmehr Singh Gulati
# Middle Name                     NaN
# Last Name                       NaN
# Title                           NaN
# Suffix                          NaN
#                        ...
# Location                        NaN
# Web Page                        NaN
# Birthday                        NaN
# Anniversary                     NaN
# Notes                           NaN
# Name: 118, Length: 61, dtype: object
# First Name     Divya Darshan Tiwari
# Middle Name                     NaN
# Last Name                       NaN
# Title                           NaN
# Suffix                          NaN
#                        ...
# Location                        NaN
# Web Page                        NaN
# Birthday                        NaN
# Anniversary                     NaN
# Notes                           NaN
# Name: 119, Length: 61, dtype: object
# First Name      Ayush Dey
# Middle Name           NaN
# Last Name      Srivastava
# Title                 Dr.
# Suffix                NaN
#                   ...
# Location              NaN
# Web Page              NaN
# Birthday              NaN
# Anniversary           NaN
# Notes                 NaN
# Name: 120, Length: 61, dtype: object
# First Name     Aryan Somesh Gupta
# Middle Name                   NaN
# Last Name                Majumder
# Title                         NaN
# Suffix                        NaN
#                       ...
# Location                      NaN
# Web Page                      NaN
# Birthday                      NaN
# Anniversary                   NaN
# Notes                         NaN
# Name: 121, Length: 61, dtype: object
# First Name     Nishtha  Kanyal
# Middle Name                NaN
# Last Name                  NaN
# Title                      NaN
# Suffix                     NaN
#                     ...
# Location                   NaN
# Web Page                   NaN
# Birthday                   NaN
# Anniversary                NaN
# Notes                      NaN
# Name: 122, Length: 61, dtype: object
# First Name     Anant Singh
# Middle Name            NaN
# Last Name              NaN
# Title                  NaN
# Suffix                 NaN
#                   ...
# Location               NaN
# Web Page               NaN
# Birthday               NaN
# Anniversary            NaN
# Notes                  NaN
# Name: 123, Length: 61, dtype: object
# First Name     Yogita Beniwal
# Middle Name               NaN
# Last Name                 NaN
# Title                     NaN
# Suffix                    NaN
#                     ...
# Location                  NaN
# Web Page                  NaN
# Birthday                  NaN
# Anniversary               NaN
# Notes                     NaN
# Name: 124, Length: 61, dtype: object
# First Name     Vinayak Sharma
# Middle Name               NaN
# Last Name                 NaN
# Title                     NaN
# Suffix                    NaN
#                     ...
# Location                  NaN
# Web Page                  NaN
# Birthday                  NaN
# Anniversary               NaN
# Notes                     NaN
# Name: 125, Length: 61, dtype: object
# First Name     Ishika Rathore
# Middle Name               NaN
# Last Name                 NaN
# Title                     NaN
# Suffix                    NaN
#                     ...
# Location                  NaN
# Web Page                  NaN
# Birthday                  NaN
# Anniversary               NaN
# Notes                     NaN
# Name: 126, Length: 61, dtype: object
# First Name     Akshit Chauhan
# Middle Name               NaN
# Last Name                 NaN
# Title                     NaN
# Suffix                    NaN
#                     ...
# Location                  NaN
# Web Page                  NaN
# Birthday                  NaN
# Anniversary               NaN
# Notes                     NaN
# Name: 127, Length: 61, dtype: object
# First Name     Piyush
# Middle Name       NaN
# Last Name         NaN
# Title             NaN
# Suffix            NaN
#                 ...
# Location          NaN
# Web Page          NaN
# Birthday          NaN
# Anniversary       NaN
# Notes             NaN
# Name: 128, Length: 61, dtype: object
# First Name     Rakshita Garg
# Middle Name              NaN
# Last Name                NaN
# Title                    NaN
# Suffix                   NaN
#                    ...
# Location                 NaN
# Web Page                 NaN
# Birthday                 NaN
# Anniversary              NaN
# Notes                    NaN
# Name: 129, Length: 61, dtype: object
# First Name     Nishtha  Kanyal
# Middle Name                NaN
# Last Name                  NaN
# Title                      NaN
# Suffix                     NaN
#                     ...
# Location                   NaN
# Web Page                   NaN
# Birthday                   NaN
# Anniversary                NaN
# Notes                      NaN
# Name: 130, Length: 61, dtype: object
# First Name     Anant Singh
# Middle Name            NaN
# ...
# Location                      NaN
# Web Page                      NaN
# Birthday                      NaN
# Anniversary                   NaN
# Notes                         NaN
# Name: 290, Length: 61, dtype: object
# First Name     Shashank Verma
# Middle Name               NaN
# Last Name                 NaN
# Title                     NaN
# Suffix                    NaN
#                     ...
# Location                  NaN
# Web Page                  NaN
# Birthday                  NaN
# Anniversary               NaN
# Notes                     NaN
# Name: 291, Length: 61, dtype: object
# First Name     Nishtha kanyal
# Middle Name               NaN
# Last Name                 NaN
# Title                     NaN
# Suffix                    NaN
#                     ...
# Location                  NaN
# Web Page                  NaN
# Birthday                  NaN
# Anniversary               NaN
# Notes                     NaN
# Name: 292, Length: 61, dtype: object
# First Name     Diya Bhardwaj
# Middle Name              NaN
# Last Name                NaN
# Title                    NaN
# Suffix                   NaN
#                    ...
# Location                 NaN
# Web Page                 NaN
# Birthday                 NaN
# Anniversary              NaN
# Notes                    NaN
# Name: 293, Length: 61, dtype: object
# First Name     Bhavya Singh
# Middle Name             NaN
# Last Name               NaN
# Title                   NaN
# Suffix                  NaN
#                    ...
# Location                NaN
# Web Page                NaN
# Birthday                NaN
# Anniversary             NaN
# Notes                   NaN
# Name: 294, Length: 61, dtype: object
# First Name     Aditya Gupta
# Middle Name             NaN
# Last Name               NaN
# Title                   NaN
# Suffix                  NaN
#                    ...
# Location                NaN
# Web Page                NaN
# Birthday                NaN
# Anniversary             NaN
# Notes                   NaN
# Name: 295, Length: 61, dtype: object
# First Name     Yuvraj singh Dhama
# Middle Name                   NaN
# Last Name                     NaN
# Title                         NaN
# Suffix                        NaN
#                       ...
# Location                      NaN
# Web Page                      NaN
# Birthday                      NaN
# Anniversary                   NaN
# Notes                         NaN
# Name: 296, Length: 61, dtype: object
# First Name     Sudhish Bisht
# Middle Name              NaN
# Last Name                NaN
# Title                    NaN
# Suffix                   NaN
#                    ...
# Location                 NaN
# Web Page                 NaN
# Birthday                 NaN
# Anniversary              NaN
# Notes                    NaN
# Name: 297, Length: 61, dtype: object
# First Name     Prabtej Singh
# Middle Name              NaN
# Last Name                NaN
# Title                    NaN
# Suffix                   NaN
#                    ...
# Location                 NaN
# Web Page                 NaN
# Birthday                 NaN
# Anniversary              NaN
# Notes                    NaN
# Name: 298, Length: 61, dtype: object
# First Name     Anurag yentrapragada
# Middle Name                     NaN
# Last Name                       NaN
# Title                           NaN
# Suffix                          NaN
#                        ...
# Location                        NaN
# Web Page                        NaN
# Birthday                        NaN
# Anniversary                     NaN
# Notes                           NaN
# Name: 299, Length: 61, dtype: object
# First Name     Shrey Sharma
# Middle Name             NaN
# Last Name               NaN
# Title                   NaN
# Suffix                  NaN
#                    ...
# Location                NaN
# Web Page                NaN
# Birthday                NaN
# Anniversary             NaN
# Notes                   NaN
# Name: 300, Length: 61, dtype: object
# First Name     Rishav Singh
# Middle Name             NaN
# Last Name               NaN
# Title                   NaN
# Suffix                  NaN
#                    ...
# Location                NaN
# Web Page                NaN
# Birthday                NaN
# Anniversary             NaN
# Notes                   NaN
# Name: 301, Length: 61, dtype: object
# First Name     Prabhu  Maken
# Middle Name              NaN
# Last Name                NaN
# Title                    NaN
# Suffix                   NaN
#                    ...
# Location                 NaN
# Web Page                 NaN
# Birthday                 NaN
# Anniversary              NaN
# Notes                    NaN
# Name: 302, Length: 61, dtype: object
# First Name     Khushi Chadha
# Middle Name              NaN
# Last Name                NaN
# Title                    NaN
# Suffix                   NaN
#                    ...
# Location                 NaN
# Web Page                 NaN
# Birthday                 NaN
# Anniversary              NaN
# Notes                    NaN
# Name: 303, Length: 61, dtype: object
# First Name     Ishit thapliyal
# Middle Name                NaN
# Last Name                  NaN
# Title                      NaN
# Suffix                     NaN
#                     ...
# Location                   NaN
# Web Page                   NaN
# Birthday                   NaN
# Anniversary                NaN
# Notes                      NaN
# Name: 304, Length: 61, dtype: object
# First Name     Harsh Nath Tiwari
# Middle Name                  NaN
# Last Name                    NaN
# Title                        NaN
# Suffix                       NaN
#                      ...
# Location                     NaN
# Web Page                     NaN
# Birthday                     NaN
# Anniversary                  NaN
# Notes                        NaN
# Name: 305, Length: 61, dtype: object
# First Name     Govind Heda
# Middle Name            NaN
# Last Name              NaN
# Title                  NaN
# Suffix                 NaN
#                   ...
# Location               NaN
# Web Page               NaN
# Birthday               NaN
# Anniversary            NaN
# Notes                  NaN
# Name: 306, Length: 61, dtype: object
# First Name     Divyansh Gupta
# Middle Name               NaN
# Last Name                 NaN
# Title                     NaN
# Suffix                    NaN
#                     ...
# Location                  NaN
# Web Page                  NaN
# Birthday                  NaN
# Anniversary               NaN
# Notes                     NaN
# Name: 307, Length: 61, dtype: object
# First Name     Anurag Kaushish
# Middle Name                NaN
# Last Name                  NaN
# Title                      NaN
# Suffix                     NaN
#                     ...
# Location                   NaN
# Web Page                   NaN
# Birthday                   NaN
# Anniversary                NaN
# Notes                      NaN
# Name: 308, Length: 61, dtype: object
# First Name     Ankur Gaharwar
# Middle Name               NaN
# Last Name                 NaN
# Title                     NaN
# Suffix                    NaN
#                     ...
# Location                  NaN
# Web Page                  NaN
# Birthday                  NaN
# Anniversary               NaN
# Notes                     NaN
# Name: 309, Length: 61, dtype: object
# First Name     Anant Singh
# Middle Name            NaN
# Last Name              NaN
# Title                  NaN
# Suffix                 NaN
#                   ...
# Location               NaN
# Web Page               NaN
# Birthday               NaN
# Anniversary            NaN
# Notes                  NaN
# Name: 310, Length: 61, dtype: object
# First Name     Aaditya vijayvargiya
# Middle Name                     NaN
# Last Name                       NaN
# Title                           NaN
# Suffix                          NaN
#                        ...
# Location                        NaN
# Web Page                        NaN
# Birthday                        NaN
# Anniversary                     NaN
# Notes                           NaN
# Name: 311, Length: 61, dtype: object
# First Name     Piyush
# Middle Name       NaN
# Last Name         NaN
# Title             NaN
# Suffix            NaN
#                 ...
# Location          NaN
# Web Page          NaN
# Birthday          NaN
# Anniversary       NaN
# Notes             NaN
# Name: 312, Length: 61, dtype: object
# First Name     Krishna Maurya
# Middle Name               NaN
# Last Name                 NaN
# Title                     NaN
# Suffix                    NaN
#                     ...
# Location                  NaN
# Web Page                  NaN
# Birthday                  NaN
# Anniversary               NaN
# Notes                     NaN
# Name: 313, Length: 61, dtype: object
# First Name     Anuj Gupta
# Middle Name           NaN
# Last Name             NaN
# Title                 NaN
# Suffix                NaN
#                   ...
# Location              NaN
# Web Page              NaN
# Birthday              NaN
# Anniversary           NaN
# Notes                 NaN
# Name: 314, Length: 61, dtype: object
# First Name     Ujjwal Kaushik
# Middle Name               NaN
# Last Name                 NaN
# Title                     NaN
# Suffix                    NaN
#                     ...
# Location                  NaN
# Web Page                  NaN
# Birthday                  NaN
# Anniversary               NaN
# Notes                     NaN
# Name: 315, Length: 61, dtype: object
# First Name     Tushar Sharma
# Middle Name              NaN
# Last Name                NaN
# Title                    NaN
# Suffix                   NaN
#                    ...
# Location                 NaN
# Web Page                 NaN
# Birthday                 NaN
# Anniversary              NaN
# Notes                    NaN
# Name: 316, Length: 61, dtype: object
# First Name     Vanshika Agarwal
# Middle Name                 NaN
# Last Name                   NaN
# Title                       NaN
# Suffix                      NaN
#                      ...
# Location                    NaN
# Web Page                    NaN
# Birthday                    NaN
# Anniversary                 NaN
# Notes                       NaN
# Name: 317, Length: 61, dtype: object
# First Name     Manjari Yagnik
# Middle Name               NaN
# Last Name                 NaN
# Title                     NaN
# Suffix                    NaN
#                     ...
# Location                  NaN
# Web Page                  NaN
# Birthday                  NaN
# Anniversary               NaN
# Notes                     NaN
# Name: 318, Length: 61, dtype: object
# First Name     Jahnavi Singh Chauhan
# Middle Name                      NaN
# Last Name                        NaN
# Title                            NaN
# Suffix                           NaN
#                        ...
# Location                         NaN
# Web Page                         NaN
# Birthday                         NaN
# Anniversary                      NaN
# Notes                            NaN
# Name: 319, Length: 61, dtype: object
# First Name     Jaanhvi Saxena
# Middle Name               NaN
# Last Name                 NaN
# Title                     NaN
# Suffix                    NaN
#                     ...
# Location                  NaN
# Web Page                  NaN
# Birthday                  NaN
# Anniversary               NaN
# Notes                     NaN
# Name: 320, Length: 61, dtype: object
# First Name     Deepanshu Kumar Jindal
# Middle Name                       NaN
# Last Name                         NaN
# Title                             NaN
# Suffix                            NaN
#                         ...
# Location                          NaN
# Web Page                          NaN
# Birthday                          NaN
# Anniversary                       NaN
# Notes                             NaN
# Name: 321, Length: 61, dtype: object
# First Name     Rishitt Gupta
# Middle Name              NaN
# Last Name                NaN
# Title                    NaN
# Suffix                   NaN
#                    ...
# Location                 NaN
# Web Page                 NaN
# Birthday                 NaN
# Anniversary              NaN
# Notes                    NaN
# Name: 322, Length: 61, dtype: object
# First Name     Vyom Singhal
# Middle Name             NaN
# Last Name               NaN
# Title                   NaN
# Suffix                  NaN
#                    ...
# Location                NaN
# Web Page                NaN
# Birthday                NaN
# Anniversary             NaN
# Notes                   NaN
# Name: 323, Length: 61, dtype: object
# First Name     Rakshita Garg
# Middle Name              NaN
# Last Name                NaN
# Title                    NaN
# Suffix                   NaN
#                    ...
# Location                 NaN
# Web Page                 NaN
# Birthday                 NaN
# Anniversary              NaN
# Notes                    NaN
# Name: 324, Length: 61, dtype: object
# First Name     Paras Verma
# Middle Name            NaN
# Last Name              NaN
# Title                  NaN
# Suffix                 NaN
#                   ...
# Location               NaN
# Web Page               NaN
# Birthday               NaN
# Anniversary            NaN
# Notes                  NaN
# Name: 325, Length: 61, dtype: object
# First Name     Panshul Saxena
# Middle Name               NaN
# Last Name                 NaN
# Title                     NaN
# Suffix                    NaN
#                     ...
# Location                  NaN
# Web Page                  NaN
# Birthday                  NaN
# Anniversary               NaN
# Notes                     NaN
# Name: 326, Length: 61, dtype: object
# First Name     Khushi Dasoar
# Middle Name              NaN
# Last Name                NaN
# Title                    NaN
# Suffix                   NaN
#                    ...
# Location                 NaN
# Web Page                 NaN
# Birthday                 NaN
# Anniversary              NaN
# Notes                    NaN
# Name: 327, Length: 61, dtype: object
# First Name     Gurmehr Singh Gulati
# Middle Name                     NaN
# Last Name                       NaN
# Title                           NaN
# Suffix                          NaN
#                        ...
# Location                        NaN
# Web Page                        NaN
# Birthday                        NaN
# Anniversary                     NaN
# Notes                           NaN
# Name: 328, Length: 61, dtype: object
# First Name     Divya Darshan Tiwari
# Middle Name                     NaN
# Last Name                       NaN
# Title                           NaN
# Suffix                          NaN
#                        ...
# Location                        NaN
# Web Page                        NaN
# Birthday                        NaN
# Anniversary                     NaN
# Notes                           NaN
# Name: 329, Length: 61, dtype: object
# First Name      Ayush Dey
# Middle Name           NaN
# Last Name      Srivastava
# Title                 Dr.
# Suffix                NaN
#                   ...
# Location              NaN
# Web Page              NaN
# Birthday              NaN
# Anniversary           NaN
# Notes                 NaN
# Name: 330, Length: 61, dtype: object
# First Name     Aryan Somesh Gupta
# Middle Name                   NaN
# Last Name                Majumder
# Title                         NaN
# Suffix                        NaN
#                       ...
# Location                      NaN
# Web Page                      NaN
# Birthday                      NaN
# Anniversary                   NaN
# Notes                         NaN
# Name: 331, Length: 61, dtype: object
# First Name      Avishek
# Middle Name         NaN
# Last Name      Majumder
# Title               NaN
# Suffix              NaN
#                  ...
# Location            NaN
# Web Page            NaN
# Birthday            NaN
# Anniversary         NaN
# Notes               NaN
# Name: 332, Length: 61, dtype: object
# First Name       Kingshuk
# Middle Name           NaN
# Last Name      Srivastava
# Title                 Dr.
# Suffix                NaN
#                   ...
# Location              NaN
# Web Page              NaN
# Birthday              NaN
# Anniversary           NaN
# Notes                 NaN
# Name: 333, Length: 61, dtype: object
